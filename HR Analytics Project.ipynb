# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# Load the sample dataset from Seaborn
data = sns.load_dataset("iris")

# %%
# Convert the species column into dummy variables
species_dummies = pd.get_dummies(data['species'], prefix='species')

# %%
# Concatenate the dummy variables with the original dataset
data = pd.concat([data, species_dummies], axis=1)

# %%
# Drop the original 'species' column
data.drop(columns=['species'], inplace=True)

# %%
# Display the first few rows of the dataset
print(data.head())

# Summary statistics
print(data.describe())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species_setosa  \
# 0           5.1          3.5           1.4          0.2            True
# 1           4.9          3.0           1.4          0.2            True
# 2           4.7          3.2           1.3          0.2            True
# 3           4.6          3.1           1.5          0.2            True
# 4           5.0          3.6           1.4          0.2            True
#
#    species_versicolor  species_virginica
# 0               False              False
# 1               False              False
# 2               False              False
# 3               False              False
# 4               False              False
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# ...

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# sepal_length          0
# sepal_width           0
# petal_length          0
# petal_width           0
# species_setosa        0
# species_versicolor    0
# species_virginica     0
# dtype: int64

# %%
# EDA: Visualize the distribution of each feature
sns.pairplot(data, diag_kind="kde")
plt.show()

# EDA: Visualize the relationship between features
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# C:\Users\91971\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
